# %%
# !git clone https://github.com/hopl1t/sokoban_rl.git
# Out:
# Cloning into 'sokoban_rl'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 84 (delta 48), reused 66 (delta 30), pack-reused 0
# Unpacking objects: 100% (84/84), done.

# %%
# current commit short hash - c1dc313
# !cd sokoban_rl && git rev-parse --short HEAD

# %%
# !pip install gym_sokoban
# !pip install gym

# %%
# !python sokoban_rl/agent.py -env PushAndPull-Sokoban-v2 -model CommonActorCritic -obs_type ROOM_STATE_VECTOR -trajectory_len 300 -epochs 300000 -lr 0.001 -discount_gamma 0.9 -scheduler_gamma 0.99 -action_type PUSH_PULL -async_env -num_env 2 -async_sleep_interval 0.2 -save_dir /content/drive/MyDrive/RL_project/saved_agents -log_dir /content/drive/MyDrive/RL_project/logs
# Out:
# Streaming output truncated to the last 5000 lines.
# episode: 70240, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 70250, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 70260, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 70270, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 70280, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 70290, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 70300, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 70310, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 70320, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 70330, reward: -14.999999999999996, total length: 149, average length: 149.0
# ...

# %%
# !python sokoban_rl/agent.py -env PushAndPull-Sokoban-v2 -model CommonActorCritic -obs_type ROOM_STATE_VECTOR -trajectory_len 300 -epochs 300000 -lr 0.0003 -discount_gamma 0.9 -scheduler_gamma 0.99 -action_type PUSH_PULL -async_env -num_env 2 -async_sleep_interval 0.2 -load /content/drive/MyDrive/RL_project/saved_agents/CommonActorCritic_PushAndPull-Sokoban-v2_2108021908.pkl
# Out:
# Streaming output truncated to the last 5000 lines.
# episode: 101550, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 101560, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 101570, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 101580, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 101590, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 101600, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 101610, reward: -13.999999999999996, total length: 149, average length: 135.0
# episode: 101620, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 101630, reward: -14.999999999999996, total length: 149, average length: 134.9
# episode: 101640, reward: -14.999999999999996, total length: 149, average length: 149.0
# ...

# %%
# !python sokoban_rl/agent.py -env PushAndPull-Sokoban-v2 -model CommonActorCritic -obs_type ROOM_STATE_VECTOR -trajectory_len 300 -epochs 300000 -lr 0.00007 -discount_gamma 0.8 -scheduler_gamma 0.99 -action_type PUSH_PULL -async_env -num_env 2 -async_sleep_interval 0.2 -load /content/drive/MyDrive/RL_project/saved_agents/CommonActorCritic_PushAndPull-Sokoban-v2_2108021908.pkl
# Out:
# Streaming output truncated to the last 5000 lines.
# episode: 64020, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 64030, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 64040, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 64050, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 64060, reward: -13.999999999999996, total length: 149, average length: 149.0
# episode: 64070, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 64080, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 64090, reward: -14.999999999999996, total length: 149, average length: 149.0
# episode: 64100, reward: -13.999999999999996, total length: 149, average length: 149.0
# episode: 64110, reward: -14.999999999999996, total length: 149, average length: 149.0
# ...
